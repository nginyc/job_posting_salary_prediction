# %% [markdown]
# # Salary Prediction from LinkedIn Job Postings - Clean Dataset

# %% [markdown]
# ## Setup

# %%
import pandas as pd, numpy as np
# Out:
# /var/folders/vm/77wrgjgj5wzbyghx353b7gym0000gn/T/ipykernel_9073/2659969340.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd, numpy as np

# %% [markdown]
# ## Read Data

# %%
df_jobs = pd.read_csv('data/jobs.csv')
df_jobs
# Out:
#             job_id                     company_name  \
# 0           921716            Corcoran Sawyer Smith
# 1          1829192                              NaN
# 2         10998357           The National Exemplar
# 3         23221523           Abrams Fensterman, LLP
# 4         35982263                              NaN
# ...            ...                              ...
# 123844  3906267117                     Lozano Smith
# 123845  3906267126                        Pinterest
# 123846  3906267131                     EPS Learning
# 123847  3906267195  Trelleborg Applied Technologies
# 123848  3906267224                        Solugenix
#
#                                                     title  \
# 0                                   Marketing Coordinator
# 1                       Mental Health Therapist/Counselor
# 2                             Assitant Restaurant Manager
# 3       Senior Elder Law / Trusts and Estates Associat...
# 4                                      Service Technician
# ...                                                   ...
# 123844                   Title IX/Investigations Attorney
# 123845       Staff Software Engineer, ML Serving Platform
# 123846               Account Executive, Oregon/Washington
# 123847                       Business Development Manager
# 123848                  Marketing Social Media Specialist
#
#                                               description  max_salary  \
# 0       Job descriptionA leading real estate firm in N...        20.0
# 1       At Aspen Therapy and Wellness , we are committ...        50.0
# 2       The National Exemplar is accepting application...     65000.0
# 3       Senior Associate Attorney - Elder Law / Trusts...    175000.0
# 4       Looking for HVAC service tech with experience ...     80000.0
# ...                                                   ...         ...
# 123844  Our Walnut Creek office is currently seeking a...    195000.0
# 123845  About Pinterest:\n\nMillions of people across ...         NaN
# 123846  Company Overview\n\nEPS Learning is a leading ...         NaN
# 123847  The Business Development Manager is a 'hunter'...         NaN
# 123848  Marketing Social Media Specialist - $70k – $75...     75000.0
#
#        pay_period                 location  company_id  med_salary  \
# 0          HOURLY            Princeton, NJ   2774458.0         NaN
# 1          HOURLY         Fort Collins, CO         NaN         NaN
# 2          YEARLY           Cincinnati, OH  64896719.0         NaN
# 3          YEARLY        New Hyde Park, NY    766262.0         NaN
# 4          YEARLY           Burlington, IA         NaN         NaN
# ...           ...                      ...         ...         ...
# 123844     YEARLY         Walnut Creek, CA     56120.0         NaN
# 123845        NaN            United States   1124131.0         NaN
# 123846        NaN              Spokane, WA  90552133.0         NaN
# 123847        NaN     Texas, United States   2793699.0         NaN
# 123848     YEARLY  San Juan Capistrano, CA     43325.0         NaN
#
#         min_salary  ... compensation_type  normalized_salary  zip_code  \
# 0             17.0  ...       BASE_SALARY            38480.0    8540.0
# 1             30.0  ...       BASE_SALARY            83200.0   80521.0
# 2          45000.0  ...       BASE_SALARY            55000.0   45202.0
# 3         140000.0  ...       BASE_SALARY           157500.0   11040.0
# 4          60000.0  ...       BASE_SALARY            70000.0   52601.0
# ...            ...  ...               ...                ...       ...
# 123844    120000.0  ...       BASE_SALARY           157500.0   94595.0
# 123845         NaN  ...               NaN                NaN       NaN
# 123846         NaN  ...               NaN                NaN   99201.0
# 123847         NaN  ...               NaN                NaN       NaN
# 123848     70000.0  ...       BASE_SALARY            72500.0   92675.0
#
#                                       company_description company_state  \
# 0       With years of experience helping local buyers ...            NJ
# 1                                                     NaN           NaN
# 2       In April of 1983, The National Exemplar began ...          Ohio
# 3       Abrams Fensterman, LLP is a full-service law f...      New York
# 4                                                     NaN           NaN
# ...                                                   ...           ...
# 123844  For more than 30 years, Lozano Smith has serve...    California
# 123845  Pinterest's mission is to bring everyone the i...    California
# 123846  EPS Learning has partnered with educators for ...            MD
# 123847  Trelleborg Applied Technologies manufactures a...    Lancashire
# 123848  Solugenix stands at the forefront of informati...    California
#
#         company_country   company_city company_zip_code  \
# 0                    US    Jersey City            07302
# 1                   NaN            NaN              NaN
# 2                    US      Mariemont            45227
# 3                    US   Lake Success            11042
# 4                   NaN            NaN              NaN
# ...                 ...            ...              ...
# 123844               US         Fresno            93720
# 123845               US  San Francisco                0
# 123846               US       Bethesda            20814
# 123847               GB       Rochdale         OL11 1TQ
# 123848               US           Brea            92823
#
#                         company_industries company_employee_count
# 0                              Real Estate                  402.0
# 1                                      NaN                    NaN
# 2                              Restaurants                   15.0
# 3                             Law Practice                  222.0
# 4                                      NaN                    NaN
# ...                                    ...                    ...
# 123844                        Law Practice                  185.0
# 123845                Software Development                 8667.0
# 123846   Education Administration Programs                  127.0
# 123847  Industrial Machinery Manufacturing                   47.0
# 123848       IT Services and IT Consulting                  862.0
#
# [123849 rows x 29 columns]

# %% [markdown]
# ## Clean Data

# %%
''''
Experience level has missing values.
Fill "NA" values with "Unknown".
'''
df_jobs['formatted_experience_level'] = df_jobs['formatted_experience_level'].fillna("Unknown")

# %%
''''
Remote allowed are all "1" and has missing values. Assume missing values are "0".
'''
df_jobs['remote_allowed'] = df_jobs['remote_allowed'].fillna(0)

# %%
'''
Fill missing values in "location", "zip_code", "company_country", "company_state", "company_city", "company_zip_code" with "Unknown".
'''
df_jobs["zip_code"] = df_jobs["zip_code"].fillna("Unknown")
df_jobs["company_country"] = df_jobs["company_country"].fillna("Unknown")
df_jobs["company_state"] = df_jobs["company_state"].fillna("Unknown")
df_jobs["company_city"] = df_jobs["company_city"].fillna("Unknown")
df_jobs["company_zip_code"] = df_jobs["company_zip_code"].fillna("Unknown")

# %% [markdown]
# ## Transform Columns

# %%
'''
As identified during EDA, salaries are heavily skewed and vary over a huge range of magnitudes.
But log salaries look more normally distributed and allow us to train more numerically stable models with better fit.
Moreover, they reduce the impact of outliers on our models.

As such, we compute log10 of normalized salary that we use as the target variable.
'''
df_jobs["normalized_salary_log10"] = np.log10(df_jobs["normalized_salary"])
# Out:
# /Users/nginyc/repos/job_posting_salary_prediction/venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
'''
Populate "location_state" from "location". 
Ensure that it is a valid state, otherwise we say it's "Unknown".
'''

us_states = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA',
    'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD',
    'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ',
    'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC',
    'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
]

df_jobs['location_state'] = df_jobs['location'].apply(lambda x: x.split(',')[-1].strip() if ',' in x else None).apply(lambda x: x if x in us_states else "Unknown")
df_jobs['location_state'].value_counts(dropna=False)
# Out:
# location_state
# Unknown    19753
# CA         11484
# TX         10271
# NY          6044
# FL          5907
# NC          4927
# IL          4480
# PA          4133
# VA          3660
# MA          3489
# OH          3421
# GA          3420
# NJ          3286
# MI          2857
# WA          2708
# AZ          2507
# CO          2318
# MD          1974
# MO          1922
# TN          1885
# WI          1849
# MN          1849
# IN          1808
# SC          1539
# CT          1191
# KY          1179
# OR          1177
# LA          1106
# AL          1004
# IA           995
# UT           968
# KS           931
# NV           907
# OK           794
# AR           665
# NE           591
# NH           559
# NM           499
# HI           425
# WV           416
# ID           413
# MS           387
# ME           377
# DE           320
# RI           306
# MT           236
# ND           235
# AK           206
# VT           181
# SD           165
# WY           125
# Name: count, dtype: int64

# %% [markdown]
# ## Export Data

# %%
'''
Based on our problem statement, here is the list of raw features (X) we would try to use to predict salaries:
1. job_id (ID column)
2. title
3. location
4. location_state
5. description
6. formatted_work_type
7. formatted_experience_level
8. remote_allowed
9. company_industries
10. company_country
11. company_state
12. company_city
13. company_description
14. company_employee_count

And here are the target variables (Y) we want to predict:
1. normalized_salary (main)
2. min_salary
3. max_salary
4. med_salary
5. pay_period
'''
FEATURE_COLUMNS = ['title', 'location', 'location_state', 'description', 'formatted_work_type', 'formatted_experience_level', 'remote_allowed',
    'company_industries', 'company_country', 'company_state', 'company_city', 'company_description', 'company_employee_count']
TARGET_COLUMNS = ['normalized_salary', 'normalized_salary_log10', 'min_salary', 'max_salary', 'med_salary', 'pay_period']

'''
As discoverd during EDA, we filter OUT:
- duplicated jobs (based on feature columns, excluding job_id)
- jobs with non-USD currency
- jobs with no salary information
- jobs with below min wage as they are bad data. <10K USD yearly is below minimum wage in US. See https://www.dol.gov/agencies/whd/minimum-wage)
- jobs with too high a salary of 1M+ as they are likely to be bad data
'''

non_duplicated = ~df_jobs.duplicated(subset=FEATURE_COLUMNS, keep='first')
only_usd = df_jobs['currency'] == 'USD'
with_salary = df_jobs['normalized_salary'].notna()
above_min_wage = df_jobs['normalized_salary'] >= 1e4
below_1M = df_jobs['normalized_salary'] <= 1e6

# For each filter, print out number of jobs filtered
for name, filter in zip(["non_duplicated", "only_usd", "with_salary", "above_min_wage", "below_1M"], [non_duplicated, only_usd, with_salary, above_min_wage, below_1M]):
    print(f"NOT {name} jobs: {len(filter) - filter.sum()}")

df_jobs_clean = df_jobs[non_duplicated & only_usd & with_salary & above_min_wage & below_1M][
    ['job_id'] + FEATURE_COLUMNS + TARGET_COLUMNS
]

df_jobs_clean
# Out:
# NOT non_duplicated jobs: 4613
# NOT only_usd jobs: 87791
# NOT with_salary jobs: 87776
# NOT above_min_wage jobs: 88193
# NOT below_1M jobs: 87814
#             job_id                                              title  \
# 0           921716                              Marketing Coordinator
# 1          1829192                  Mental Health Therapist/Counselor
# 2         10998357                        Assitant Restaurant Manager
# 3         23221523  Senior Elder Law / Trusts and Estates Associat...
# 4         35982263                                 Service Technician
# ...            ...                                                ...
# 123837  3906265414                             Contract Administrator
# 123839  3906266165                             Catering Event Manager
# 123843  3906266272                                   Quality Engineer
# 123844  3906267117                   Title IX/Investigations Attorney
# 123848  3906267224                  Marketing Social Media Specialist
#
#                        location location_state  \
# 0                 Princeton, NJ             NJ
# 1              Fort Collins, CO             CO
# 2                Cincinnati, OH             OH
# 3             New Hyde Park, NY             NY
# 4                Burlington, IA             IA
# ...                         ...            ...
# 123837               Irvine, CA             CA
# 123839     Greater Indianapolis        Unknown
# 123843               Irvine, CA             CA
# 123844         Walnut Creek, CA             CA
# 123848  San Juan Capistrano, CA             CA
#
#                                               description formatted_work_type  \
# 0       Job descriptionA leading real estate firm in N...           Full-time
# 1       At Aspen Therapy and Wellness , we are committ...           Full-time
# 2       The National Exemplar is accepting application...           Full-time
# 3       Senior Associate Attorney - Elder Law / Trusts...           Full-time
# 4       Looking for HVAC service tech with experience ...           Full-time
# ...                                                   ...                 ...
# 123837  Position: Clinical Contracts Analyst, Req#: 63...            Contract
# 123839  This role handles all the onsite catering and ...           Part-time
# 123843  Position: Quality Engineer I (Complaint Invest...            Contract
# 123844  Our Walnut Creek office is currently seeking a...           Full-time
# 123848  Marketing Social Media Specialist - $70k – $75...           Full-time
#
#        formatted_experience_level  remote_allowed  \
# 0                         Unknown             0.0
# 1                         Unknown             0.0
# 2                         Unknown             0.0
# 3                         Unknown             0.0
# 4                         Unknown             0.0
# ...                           ...             ...
# 123837           Mid-Senior level             0.0
# 123839                  Associate             0.0
# 123843           Mid-Senior level             0.0
# 123844           Mid-Senior level             0.0
# 123848           Mid-Senior level             0.0
#
#                    company_industries company_country company_state  \
# 0                         Real Estate              US            NJ
# 1                                 NaN         Unknown       Unknown
# 2                         Restaurants              US          Ohio
# 3                        Law Practice              US      New York
# 4                                 NaN         Unknown       Unknown
# ...                               ...             ...           ...
# 123837        Staffing and Recruiting              US            MA
# 123839        Staffing and Recruiting              US       Indiana
# 123843        Staffing and Recruiting              US            MA
# 123844                   Law Practice              US    California
# 123848  IT Services and IT Consulting              US    California
#
#         company_city                                company_description  \
# 0        Jersey City  With years of experience helping local buyers ...
# 1            Unknown                                                NaN
# 2          Mariemont  In April of 1983, The National Exemplar began ...
# 3       Lake Success  Abrams Fensterman, LLP is a full-service law f...
# 4            Unknown                                                NaN
# ...              ...                                                ...
# 123837        Natick  Founded in 2002, TalentBurst is an MBE and JCC...
# 123839  Indianapolis  Athena Recruiting provides recruitment service...
# 123843        Natick  Founded in 2002, TalentBurst is an MBE and JCC...
# 123844        Fresno  For more than 30 years, Lozano Smith has serve...
# 123848          Brea  Solugenix stands at the forefront of informati...
#
#         company_employee_count  normalized_salary  normalized_salary_log10  \
# 0                        402.0            38480.0                 4.585235
# 1                          NaN            83200.0                 4.920123
# 2                         15.0            55000.0                 4.740363
# 3                        222.0           157500.0                 5.197281
# 4                          NaN            70000.0                 4.845098
# ...                        ...                ...                      ...
# 123837                   668.0            83200.0                 4.920123
# 123839                     5.0            57500.0                 4.759668
# 123843                   668.0            83200.0                 4.920123
# 123844                   185.0           157500.0                 5.197281
# 123848                   862.0            72500.0                 4.860338
#
#         min_salary  max_salary  med_salary pay_period
# 0             17.0        20.0         NaN     HOURLY
# 1             30.0        50.0         NaN     HOURLY
# 2          45000.0     65000.0         NaN     YEARLY
# 3         140000.0    175000.0         NaN     YEARLY
# 4          60000.0     80000.0         NaN     YEARLY
# ...            ...         ...         ...        ...
# 123837        35.0        45.0         NaN     HOURLY
# 123839     50000.0     65000.0         NaN     YEARLY
# 123843        30.0        50.0         NaN     HOURLY
# 123844    120000.0    195000.0         NaN     YEARLY
# 123848     70000.0     75000.0         NaN     YEARLY
#
# [34857 rows x 20 columns]

# %%
df_jobs_clean.sample().T
# Out:
#                                                                         75688
# job_id                                                             3903456010
# title                                                              Controller
# location                                   Portland, Oregon Metropolitan Area
# location_state                                                        Unknown
# description                 Scion Staffing has been engaged to conduct an ...
# formatted_work_type                                                 Full-time
# formatted_experience_level                                   Mid-Senior level
# remote_allowed                                                            0.0
# company_industries                                    Staffing and Recruiting
# company_country                                                            US
# company_state                                                      California
# company_city                                                    San Francisco
# company_description         Do you need to hire exceptional talent? Scion ...
# company_employee_count                                                   50.0
# normalized_salary                                                    114400.0
# normalized_salary_log10                                              5.058426
# min_salary                                                               48.0
# max_salary                                                               62.0
# med_salary                                                                NaN
# pay_period                                                             HOURLY

# %%
df_jobs_clean.to_csv('data/jobs_clean.csv', index=False)
